# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
housing = pd.read_csv('AmesHousing.csv')

# %%
housing.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# ...

# %%
housing.describe()
# Out:
#             Order           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2930.00000  2.930000e+03  2930.000000   2440.000000    2930.000000
# mean   1465.50000  7.144645e+08    57.387372     69.224590   10147.921843
# std     845.96247  1.887308e+08    42.638025     23.365335    7880.017759
# min       1.00000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     733.25000  5.284770e+08    20.000000     58.000000    7440.250000
# 50%    1465.50000  5.354536e+08    50.000000     68.000000    9436.500000
# 75%    2197.75000  9.071811e+08    70.000000     80.000000   11555.250000
# max    2930.00000  1.007100e+09   190.000000    313.000000  215245.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2930.000000   2930.000000  2930.000000     2930.000000   2907.000000
# mean       6.094881      5.563140  1971.356314     1984.266553    101.896801
# ...

# %%
print(housing.columns)
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %%
print(housing)
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
#idk kva ditta gjer enda
#Dropper uregistrerte tables
print(housing.dropna())
# Out:
# Empty DataFrame
# ...

# %%
#dropper brackets med data som ikkje viser
print(housing.drop("Pool Area", axis=1))
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
print(housing[housing["Yr Sold"] == 2010])
# Out:
#      Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0        1  526301100           20        RL         141.0     31770   Pave
# 1        2  526350040           20        RH          80.0     11622   Pave
# 2        3  526351010           20        RL          81.0     14267   Pave
# 3        4  526353030           20        RL          93.0     11160   Pave
# 4        5  527105010           60        RL          74.0     13830   Pave
# ..     ...        ...          ...       ...           ...       ...    ...
# 336    337  923276250           90        RL          70.0      7700   Pave
# 337    338  923426070           60        RL          63.0     10475   Pave
# 338    339  924100050           50        RL          68.0     10544   Pave
# 339    340  924151040           20        RL          76.0      9892   Pave
# 340    341  924152030           60        RL          74.0     12961   Pave
#
# ...

# %%
print(housing[housing["Pool Area"] <= 1])
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
#Checks datatypes
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
#  15  Condition 2      2930 non-null   object
# ...

# %%
#preprocessing done here

# %%
#Data-visualisason

import seaborn as sns
sns.set(color_codes=True)

# %%
#Creates a bar plot
sns.barplot(housing["SalePrice"])
# Out:
# <Axes: ylabel='SalePrice'>

# %%
#shows bar and swingings of year sold
sns.distplot(housing["Yr Sold"])
# Out:
# /tmp/ipykernel_25589/1801011830.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(housing["Yr Sold"])
# <Axes: xlabel='Yr Sold', ylabel='Density'>

# %%
sns.pairplot(housing[['Yr Sold','Overall Qual','SalePrice']])

# %%
sns.lmplot(x="Overall Qual", y="SalePrice", data = housing)

# %%
from sklearn.linear_model import LinearRegression

# %%
sns.scatterplot(x = 'Overall Qual', y = 'SalePrice', data = housing)
# Out:
# <Axes: xlabel='Overall Qual', ylabel='SalePrice'>

# %%
sns.scatterplot(x = housing['Overall Qual'], y = housing['Pool Area'])
# Out:
# <Axes: xlabel='Overall Qual', ylabel='Pool Area'>

# %%
sns.regplot(x = 'Overall Qual', y = 'SalePrice', data = housing)
# Out:
# <Axes: xlabel='Overall Qual', ylabel='SalePrice'>

# %%
#end of visualizion

# %%
#start of feauture enginering
housing
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
df = housing.sample(frac=1, random_state=2)
train_df = df[:2344]
train_df = train_df.reset_index(drop=True)
test_df = df[2344:]
test_df = test_df.reset_index(drop=True)

train_df
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1573  916325080           20        RL           NaN     15498   Pave
# 1      2730  905300080           20        RL         100.0     13350   Pave
# 2      1700  528114050           20        RL         110.0     14977   Pave
# 3      1070  528180110          120        RL          58.0     10110   Pave
# 4      1437  907181120           60        RL          68.0      8998   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2339   1540  909425085           50        RL          70.0     12392   Pave
# 2340   1579  916386180           60        RL          81.0     12018   Pave
# 2341   2061  905105260           20        RL          66.0      7742   Pave
# 2342   1472  907295100           90        RM          83.0     10126   Pave
# 2343   2660  902325050           75        RM          60.0     10800   Pave
#
# ...

# %%
y_train = train_df["Pool Area"].to_numpy()
y_test = test_df["Pool Area"].to_numpy()

y_train.shape, y_test.shape

((2500,),(200,))
# Out:
# ((2500,), (200,))

# %%
test_df
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      2166  907420060           60        RL          64.0      8333   Pave
# 1      1095  528290010           60        RL          60.0     15384   Pave
# 2       519  528458040           20        FV          72.0      8640   Pave
# 3       422  528102140           60        RL         110.0     14257   Pave
# 4      1570  914476450           20        RL          74.0      9990   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 1225   2515  533241010           60        FV         114.0      8314   Pave
# 1226   2348  527354040           20        RL          80.0     10400   Pave
# 1227   1609  923426010           20        RL          74.0     12395   Pave
# 1228   2542  534275010           20        RL           NaN     10659   Pave
# 1229   2576  535176050           20        RL          80.0     11600   Pave
#
# ...

# %%
#Get error of baseline model that uses the average Pool Area in train_df

from sklearn.metrics import mean_absolute_error

average_median_pool_area = train_df["Pool Area"].mean()
baseline_model_test_predictions = [average_median_pool_area] * len(test_df)

mean_absolute_error(baseline_model_test_predictions, y_test)
# Out:
# 4.643607843137255

# %%
#gjer det samme for X imorga min 11:48 i videon

# %%
#1.Demansionality Reduction (PCA)
# Observere correlation between "Pool Area" and total price
#Sjekker korelasionen

train_df[['SalePrice', 'Lot Area','Pool Area']].corr()
# Out:
#            SalePrice  Lot Area  Pool Area
# SalePrice   1.000000  0.267013   0.108330
# Lot Area    0.267013  1.000000   0.083525
# Pool Area   0.108330  0.083525   1.000000

# %%
train_df[['SalePrice', 'Lot Area','Pool Area','MS SubClass']].corr()
# Out:
#              SalePrice  Lot Area  Pool Area  MS SubClass
# SalePrice     1.000000  0.267013   0.108330    -0.059087
# Lot Area      0.267013  1.000000   0.083525    -0.213985
# Pool Area     0.108330  0.083525   1.000000    -0.016041
# MS SubClass  -0.059087 -0.213985  -0.016041     1.000000

# %%
#This one has good coelation

train_df[['SalePrice', 'Year Remod/Add','Overall Qual']].corr()
# Out:
#                 SalePrice  Year Remod/Add  Overall Qual
# SalePrice        1.000000        0.519373       0.80134
# Year Remod/Add   0.519373        1.000000       0.56417
# Overall Qual     0.801340        0.564170       1.00000

# %%
# Get X_train_3 which has "sale price","Lot Area" and
X_train_3 = train_df[['SalePrice', 'Year Remod/Add','Overall Qual']].to_numpy()

X_train_3.shape

#Choose the amount of training data

(800,3)
# Out:
# (800, 3)

# %%
# Get X_test_3 which has SalePrice, year remod/add and Overall quality.
# The test data training data.
# 2000 training data

X_test_3 = test_df[['SalePrice', 'Year Remod/Add','Overall Qual']].to_numpy()
X_test_3.shape

(2000, 3)
# Out:
# (2000, 3)

# %%
# Get error of random forest training on just (X_train_3, y train) and testing on (X_test_3, y_test)
#Forrest training
# On average our model was of with 3
from sklearn.ensemble import RandomForestRegressor

forest_base = RandomForestRegressor(n_estimators=50, max_depth=5).fit(X_train_3, y_train)
forest_base_test_predictions = forest_base.predict(X_test_3)
mean_absolute_error(y_test,forest_base_test_predictions)
# Out:
# 3.871670668004506

# %%
#Train PCA (Linear Dimensionality Reduction) with 2-feature output

from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca = pca.fit(X_train_3)

pca

PCA(n_components=2)
# Out:
# PCA(n_components=2)

# %%
# Use PCA to transform X_train_3 and X_test_3
X_train_pca = pca.transform(X_train_3)
X_test_pca = pca.transform(X_test_3)

X_train_pca.shape, X_test_pca.shape

((2000,2), (800,3))
# Out:
# ((2000, 2), (800, 3))

# %%
# Get error of Random Forest training on (X_train_pca, y_train) and testing on (X_test_pca, y_test)
# PCA did around close to the same result
forest_pca = RandomForestRegressor(n_estimators=50, max_depth=5).fit(X_train_pca, y_train)
forest_pca_test_predictions = forest_pca.predict(X_test_pca)
mean_absolute_error(y_test, forest_pca_test_predictions)
# Out:
# 4.3615273841023585

# %%
X_train_3
# Out:
# array([[287000,   1976,      8],
#        [142500,   1974,      5],
#        [440000,   2007,      8],
#        ...,
#        [333168,   1999,      9],
#        [167300,   1971,      6],
#        [375000,   2007,      8]], dtype=int64)
